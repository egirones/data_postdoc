# %%
import os
import pandas as pd
import pickle
import time
import re
import requests
import tqdm

# %%
with open("./klimaatadaptatie/entries.pickle", "rb") as f:
    entries = pickle.load(f)

# %%
total = 0
for i in entries:
    if entries[i].get("text"):
        total += 1
print(total)
# Out:
# 20309

# %%
bekendmaking = "./klimaatadaptatie/metadata/sources/bekendmaking.tsv"
notubiz = "./klimaatadaptatie/metadata/sources/notubiz.tsv"
overheid = "./klimaatadaptatie/metadata/sources/overheid.tsv"
bestuurlijke = "./klimaatadaptatie/metadata/sources/bestuurlijke.tsv"

# %%
df_b = pd.read_csv(bekendmaking, sep="\t")
df_b["from"] = "bekendmakig"
df_n = pd.read_csv(notubiz, sep="\t")
df_n["from"] = "notubiz"
df_o = pd.read_csv(overheid, sep="\t")
df_o["from"] = "overheid"
df_b2 = pd.read_csv(bestuurlijke, sep="\t")
df_b2["from"] = "bestuurlijke"

# %%
df_b.columns, df_n.columns, df_o.columns, df_b2.columns
# Out:
# (Index(['name', 'url', 'old_id', 'id', 'date', 'organization', 'from'], dtype='object'),
#  Index(['name', 'url', 'date', 'format', 'type_doc', 'id', 'organization',
#         'description', 'from', 'exists'],
#        dtype='object'),
#  Index(['page', 'name', 'url', 'old_id', 'id', 'date', 'organization', 'from'], dtype='object'),
#  Index(['url', 'name', 'date', 'text', 'organization', 'id', 'description',
#         'from'],
#        dtype='object'))

# %%
df = pd.concat([df_b, df_n, df_o, df_b2])
df.shape
# Out:
# (26419, 13)

# %%
df = df.reset_index()
df.drop('index', inplace=True, axis=1)

# %%
df["organization"] = df["organization"].str.lower()

# %%
df[df["id"] == "zaanstad-9999555"]
# Out:
#                                        name  \
# 24912  Accountantsverslag Zaanstad 2022.pdf
#
#                                                      url old_id  \
# 24912  https://zaanstad.bestuurlijkeinformatie.nl/lib...    NaN
#
#                      id        date organization          from format  \
# 24912  zaanstad-9999555  2023-05-25     zaanstad  bestuurlijke    NaN
#
#       type_doc description exists  page  \
# 24912      NaN         NaN    NaN   NaN
#
#                                                     text
# 24912  Raadsvergadering - donderdag 25 mei 2023 00:00...

# %%
def get_invalid_date(x):
    if x == "-1":
        return "01-01-1900"
    return x

df["date"] = df["date"].apply(lambda x: get_invalid_date(x))

# %%
def replace_month(text):
    if type(text) == float:
        return "01-01-1900"
    for i, k in enumerate(["januari", "februari", "maart", "april", "mei", "juni", "juli", "augustus","september", "oktober", "november", "december"]):
        k2 = f" {k} "
        if k2 in text:
            return text.replace(k2,f"-{str(i+1)}-").strip().split(" ", 1)[0]
    return text.split(" ", 1)[0]

def to_datetime(x):
    return x.to_pydatetime()

# %%
df["date"] = df["date"].apply(lambda x: replace_month(x))
df["date"] = pd.to_datetime(df["date"],format="mixed", dayfirst=True, errors="coerce")
df["date"] = df["date"].apply(lambda x: to_datetime(x))

# %%
df.columns
# Out:
# Index(['name', 'url', 'old_id', 'id', 'date', 'organization', 'from', 'format',
#        'type_doc', 'description', 'exists', 'page', 'text'],
#       dtype='object')

# %%
df.to_csv("./klimaatadaptatie/metadata/metadata.tsv", sep="\t")
df.to_csv("../../klimaat_research/data/metadata.tsv", sep="\t")

# %%
df_dict = df.to_dict(orient="index")

# %%
tbr= {}
for i in df_dict:
    data = df_dict[i]
    new_id = df_dict[i]["id"]
    tbr[new_id] = data

# %%
for i in tbr:
    del tbr[i]["id"]

# %%
def split_paragraphs(text, min_length=30):
    """
    Split paragraphs based on new space. If the paragraph has less minimum length, it will be ommitted.  
    """
    texts_tbr = []
    texts = re.split(r'\n', text)
    for t in texts:
        if len(t) > min_length:
            texts_tbr.append(t)
    return texts_tbr

# %%
still_to_check = {}
still_to_check["notubiz"] = []
still_to_check["bekendmakig"] = []
still_to_check["overheid"] = []
still_to_check["bestuurlijke"] = []
for i in tbr:
    try:
        with open(f"./klimaatadaptatie/txt/{i}.txt", "r") as f:
            text = f.read()

        new_text = re.sub(r'\n(?!\n)', ' ', text).strip()
        new_text = re.sub(r'\s{2,}', ' ', new_text).strip()
        if len(new_text) > 50:
            tbr[i]["text"] = new_text.strip()
        else:
            tbr[i]["text"] = 0.01
            
    except FileNotFoundError:
        source = tbr[i]["from"]
        u = tbr[i]["url"]
        still_to_check[source].append((i, u))

# %%
total = 0
to_delete = []
for i in tbr:
    text = tbr[i].get("text")
    if text:
        if type(text) == str:
            total += 1
        else:
            to_delete.append(i)
    else:
        to_delete.append(i)
print(total, len(to_delete))
# Out:
# 20309 4769

# %%
for i in to_delete:
    del tbr[i]

# %%
len(tbr.keys())
# Out:
# 20309

# %%
with open("./klimaatadaptatie/entries.pickle", "wb") as f:
    pickle.dump(tbr, f)

# %%
with open("../../klimaat_research/data/entries.pickle", "wb") as f:
    pickle.dump(tbr, f)

# %%
with open("./klimaatadaptatie/entries_to_check.pickle", "wb") as f:
    pickle.dump(still_to_check, f)

# %%
with open("./klimaatadaptatie/entries_to_check.pickle", "rb") as f:
    still_to_check = pickle.load(f)

# %%
already_existing = [i.split(".")[0] for i in os.listdir("./klimaatadaptatie/pdf")]

# %%
still_to_check["overheid"]
# Out:
# [('tweede_kamer-7566098',
#   'https://open.overheid.nl/Details/oep-49380fa5d652b27ea130a02a71cee78947566098/2?hit=26&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-aed2ac5',
#   'https://open.overheid.nl/Details/oep-5eaaf276-f7f4-47d7-b864-b14e1aed2ac5/1?hit=27&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-f01cc05',
#   'https://open.overheid.nl/Details/oep-fef6df48b305df08343f1351f32538cc0f01cc05/2?hit=28&text=klimaatadaptatie&page=1&count=50'),
#  ('infrastructuur_en_waterstaat-ad179f6',
#   'https://open.overheid.nl/Details/ronl-e95aeb70-d42a-4558-b52f-76badad179f6/1?hit=35&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-5b116fd',
#   'https://open.overheid.nl/Details/oep-27d68244222162527c5f1b5afcae1be885b116fd/2?hit=40&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-bbf4332',
#   'https://open.overheid.nl/Details/oep-efe5e858a05685471b29753053da5d7d8bbf4332/1?hit=41&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-a92f14a',
#   'https://open.overheid.nl/Details/oep-6ea0b1da9d85d7e333525b899fb9f601da92f14a/1?hit=43&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-c17ef19',
#   'https://open.overheid.nl/Details/oep-72a1f027940123f5f6a5924a88ef8be13c17ef19/1?hit=44&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-29a8c02',
#   'https://open.overheid.nl/Details/oep-51e0f0091347e17f8c067cf8090f9e17229a8c02/2?hit=45&text=klimaatadaptatie&page=1&count=50'),
#  ('landbouw_natuur_en_voedselkwaliteit-8be4d1f',
#   'https://open.overheid.nl/Details/ronl-a515755ad8628cf897f9ad37a83ec97668be4d1f/1?hit=46&text=klimaatadaptatie&page=1&count=50'),
#  ('tweede_kamer-aaf2ced',
#   'https://open.overheid.nl/Details/oep-a6b8f111db467c6cd660a939900cbd3b0aaf2ced/2?hit=52&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-04b13b4',
#   'https://open.overheid.nl/Details/oep-a006d943efe6e7a84576f287cba14d78804b13b4/1?hit=53&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-21e65bd',
#   'https://open.overheid.nl/Details/oep-c917d39e62e32b921163212c21c2e9cc521e65bd/2?hit=56&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-f915222',
#   'https://open.overheid.nl/Details/oep-e302f954a85b67449dd2e0ea3adc08500f915222/1?hit=58&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-7750161',
#   'https://open.overheid.nl/Details/oep-efff9e7c8ea605731defe448845bcf0df7750161/1?hit=65&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-dfe9b0c',
#   'https://open.overheid.nl/Details/oep-064bd69e9b02dcd4a8feaa85728fe9b20dfe9b0c/1?hit=68&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-2397236',
#   'https://open.overheid.nl/Details/oep-32a27f98e7e3a59e533da261ced6bcfdc2397236/1?hit=69&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-ec48ca4',
#   'https://open.overheid.nl/Details/oep-2e73a711a5e954dc7278189e2b20195bbec48ca4/1?hit=76&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-4228c87',
#   'https://open.overheid.nl/Details/oep-7f57507c714d55843af3c2970169d45bf4228c87/1?hit=77&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-90504c1',
#   'https://open.overheid.nl/Details/oep-db6b2dbefbd44ed72b1c5e225fef71cf290504c1/1?hit=79&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-aef6201',
#   'https://open.overheid.nl/Details/oep-546ec2817222f9add90c90ebbacfc5c3daef6201/1?hit=80&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-ba5a327',
#   'https://open.overheid.nl/Details/oep-37c9e5f57ff76237a37e08411c31eb020ba5a327/1?hit=81&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-1c77ad9',
#   'https://open.overheid.nl/Details/oep-2ef711a3187d2069f3fabd69345b960111c77ad9/1?hit=82&text=klimaatadaptatie&count=50&page=2'),
#  ('infrastructuur_en_waterstaat-1e3463e',
#   'https://open.overheid.nl/Details/ronl-02ce375c290b8a1dadee5f42a2f3d57b41e3463e/1?hit=84&text=klimaatadaptatie&count=50&page=2'),
#  ('infrastructuur_en_waterstaat-047f224',
#   'https://open.overheid.nl/Details/ronl-74902f51-d2d8-494f-b351-8da11047f224/1?hit=85&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-52b4061',
#   'https://open.overheid.nl/Details/oep-d27d5d8a0e92bd042dda052e894fa8b8352b4061/1?hit=86&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-42b81eb',
#   'https://open.overheid.nl/Details/oep-1ab0e587e65b1b7d4eaab18184c8b894c42b81eb/1?hit=89&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-dca3f35',
#   'https://open.overheid.nl/Details/oep-c87da2a652250f4ed7e502d6720514f56dca3f35/1?hit=98&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-49822e4',
#   'https://open.overheid.nl/Details/oep-3e66a6c61e6b7d45afa632c2880bab63849822e4/1?hit=99&text=klimaatadaptatie&count=50&page=2'),
#  ('tweede_kamer-0da782a',
#   'https://open.overheid.nl/Details/oep-9f785efdf4cbe770af72e0a7d65c611650da782a/1?hit=102&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-1a68152',
#   'https://open.overheid.nl/Details/oep-9fca6a8d4f4be1de1dfd68ad9b46c434d1a68152/1?hit=103&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-7ebdc03',
#   'https://open.overheid.nl/Details/oep-6b6048f4f1dad15aceb792f6770abda7b7ebdc03/1?hit=104&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-3c875a4',
#   'https://open.overheid.nl/Details/oep-ed41ec2c730ffb22701c04e88cb32664b3c875a4/1?hit=105&text=klimaatadaptatie&count=50&page=3'),
#  ('infrastructuur_en_waterstaat-dd27d96',
#   'https://open.overheid.nl/Details/ronl-c881024a-81b2-4aaf-a3df-add5cdd27d96/1?hit=108&text=klimaatadaptatie&count=50&page=3'),
#  ('eerste_kamer-619ac73',
#   'https://open.overheid.nl/Details/oep-0e473fef6d9dd67b6346174ff02235550619ac73/1?hit=110&text=klimaatadaptatie&count=50&page=3'),
#  ('onderwijs_cultuur_en_wetenschap-2ae2d02',
#   'https://open.overheid.nl/Details/ronl-df426fdd-2c07-40a8-ad71-a53a12ae2d02/1?hit=114&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-ec4f46a',
#   'https://open.overheid.nl/Details/oep-82caaeec21d8ee4449dae60e6fb2dd32aec4f46a/1?hit=115&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-a4de95b',
#   'https://open.overheid.nl/Details/oep-e2352de3d10bb7bce39e7fbbba1332ed4a4de95b/1?hit=118&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-642e322',
#   'https://open.overheid.nl/Details/oep-d3bc0093ed3fe2713d5a0e04dce8eb55a642e322/1?hit=122&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-36b9685',
#   'https://open.overheid.nl/Details/oep-bc5c9b8fca14dc73343b9a5178f4aacbb36b9685/1?hit=123&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-b0188eb',
#   'https://open.overheid.nl/Details/oep-cc2fa98acafb241de5f68bd38ef0bae8cb0188eb/1?hit=128&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-136d218',
#   'https://open.overheid.nl/Details/oep-2749bb609db79e141be7b01bc26aa5a5f136d218/2?hit=129&text=klimaatadaptatie&count=50&page=3'),
#  ('eerste_kamer-d7aa5dc',
#   'https://open.overheid.nl/Details/oep-ff31576457646e0d64786fe4b9f3eec0fd7aa5dc/1?hit=130&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-4214232',
#   'https://open.overheid.nl/Details/oep-ab670f4e38c5718b88910d35bac3aa3234214232/1?hit=131&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-f2a6532',
#   'https://open.overheid.nl/Details/oep-e255df1104ef03d23b8cf6204bc2039f9f2a6532/2?hit=134&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-a792ed1',
#   'https://open.overheid.nl/Details/oep-1e40916d09ed3945e2f9935f61db2c8a1a792ed1/2?hit=135&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-592e761',
#   'https://open.overheid.nl/Details/oep-74e5a4dca5b2c12bc8e6279d8180300dd592e761/2?hit=137&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-5c5eab9',
#   'https://open.overheid.nl/Details/oep-3cd8c8e758953145c9bf16383e7200a155c5eab9/1?hit=138&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-2a265c5',
#   'https://open.overheid.nl/Details/oep-2d94ee3f661788950a8b0d9a6f5cfc3762a265c5/1?hit=139&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-6b68ec7',
#   'https://open.overheid.nl/Details/oep-550b890355b60783f80668dc2bba62fa56b68ec7/1?hit=141&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-f6f7b05',
#   'https://open.overheid.nl/Details/oep-001d3b050ddb590f9d1ae917f3a8bc02cf6f7b05/2?hit=145&text=klimaatadaptatie&count=50&page=3'),
#  ('infrastructuur_en_waterstaat-ef0ce57',
#   'https://open.overheid.nl/Details/ronl-b05f63ab-f2d5-4fba-8aca-1c7e2ef0ce57/1?hit=148&text=klimaatadaptatie&count=50&page=3'),
#  ('tweede_kamer-5e35e5d',
#   'https://open.overheid.nl/Details/oep-53137211-40ca-4830-b089-150275e35e5d/1?hit=152&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-f02f6f3',
#   'https://open.overheid.nl/Details/oep-0e0448afcb655a3306730dfad01795758f02f6f3/1?hit=166&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-6f7d859',
#   'https://open.overheid.nl/Details/oep-6ca8d29ca7b0a48631707da87ad6ae44d6f7d859/1?hit=167&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-c7eb852',
#   'https://open.overheid.nl/Details/oep-82138c2c9b0449e2886b097e6d754fc5ec7eb852/1?hit=170&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-eeb73c1',
#   'https://open.overheid.nl/Details/oep-9ba7232c00f264e3043a5756a204b3d20eeb73c1/1?hit=171&text=klimaatadaptatie&count=50&page=4'),
#  ('infrastructuur_en_waterstaat-80ff9a2',
#   'https://open.overheid.nl/Details/ronl-8b621c31-5504-48b8-a6bf-0ab9080ff9a2/1?hit=174&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-4b70f9c',
#   'https://open.overheid.nl/Details/oep-ee4f1f9b51d800219d301b675b85f182e4b70f9c/2?hit=176&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-93c1319',
#   'https://open.overheid.nl/Details/oep-b0290a573c8ea0b369544ae0535af363993c1319/1?hit=184&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-4f84125',
#   'https://open.overheid.nl/Details/oep-a3109111ba7972a5ea7452b00183e76604f84125/1?hit=192&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-52f1ad7',
#   'https://open.overheid.nl/Details/oep-e024077991cc0d7803d004fbe182114bd52f1ad7/1?hit=197&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-2d5e7e2',
#   'https://open.overheid.nl/Details/oep-490394a0cfb6e24dff42c214ed286105c2d5e7e2/2?hit=198&text=klimaatadaptatie&count=50&page=4'),
#  ('tweede_kamer-01fddfb',
#   'https://open.overheid.nl/Details/oep-9895bb943437da347db5909ea72df494401fddfb/2?hit=201&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-636a180',
#   'https://open.overheid.nl/Details/oep-43e431babace2c30247e4bff5f0cadc36636a180/1?hit=209&text=klimaatadaptatie&count=50&page=5'),
#  ('infrastructuur_en_waterstaat-454b6e7',
#   'https://open.overheid.nl/Details/ronl-803f8c75-477d-4a16-b796-b0465454b6e7/1?hit=210&text=klimaatadaptatie&count=50&page=5'),
#  ('infrastructuur_en_waterstaat-0b0a56f',
#   'https://open.overheid.nl/Details/ronl-fe9653db85d27d7b17c27f437335cf8630b0a56f/3?hit=211&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-5b3006e',
#   'https://open.overheid.nl/Details/oep-008b58c5f3989b91b8bbe0390820890185b3006e/1?hit=213&text=klimaatadaptatie&count=50&page=5'),
#  ('eerste_kamer-9764086',
#   'https://open.overheid.nl/Details/oep-6afad6f9-6c42-4473-a8c3-14cd19764086/1?hit=214&text=klimaatadaptatie&count=50&page=5'),
#  ('infrastructuur_en_waterstaat-703e01c',
#   'https://open.overheid.nl/Details/ronl-2b4e9997-3fce-4ff1-be3a-9f6df703e01c/1?hit=215&text=klimaatadaptatie&count=50&page=5'),
#  ('infrastructuur_en_waterstaat-de0a46d',
#   'https://open.overheid.nl/Details/ronl-84cd176e-d4d5-437e-b669-3ff9dde0a46d/1?hit=216&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-728a16f',
#   'https://open.overheid.nl/Details/oep-4670f570ef92e01f504472bdf613b9424728a16f/1?hit=217&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-5cbf780',
#   'https://open.overheid.nl/Details/oep-030d38d3df3b2e9d3400fe9dec36bbc4a5cbf780/1?hit=219&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-e211664',
#   'https://open.overheid.nl/Details/oep-857c839f08778407df0a66e7797651823e211664/2?hit=220&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-41123a4',
#   'https://open.overheid.nl/Details/oep-e8fef74f6a6a77e73a28515dd0dd7171741123a4/1?hit=227&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-db7acba',
#   'https://open.overheid.nl/Details/oep-0b2c77fbadb88e5ab61e60b2eabaa475fdb7acba/1?hit=230&text=klimaatadaptatie&count=50&page=5'),
#  ('eerste_kamer-5a56073',
#   'https://open.overheid.nl/Details/oep-808e8f590b63d0dce91a4c89eedb433685a56073/1?hit=231&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-2ee9f59',
#   'https://open.overheid.nl/Details/oep-2afc45dcf6a994b7220d7b04fca334a742ee9f59/2?hit=232&text=klimaatadaptatie&count=50&page=5'),
#  ('eerste_kamer-da9876e',
#   'https://open.overheid.nl/Details/oep-061d5cdd7cd6692468ae7bc3d4a88249fda9876e/1?hit=235&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-01d86ad',
#   'https://open.overheid.nl/Details/oep-da2034f4759c61661fb3e959d0724fb8801d86ad/2?hit=240&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-92f652d',
#   'https://open.overheid.nl/Details/oep-23270760291b6e2e7a81f0c7f1257693192f652d/1?hit=241&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-2cb9c83',
#   'https://open.overheid.nl/Details/oep-7aa6efe8b394a6bf877baeb1aad3291a02cb9c83/1?hit=242&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-147c108',
#   'https://open.overheid.nl/Details/oep-60519774892d4eb49fd45116dc0f517da147c108/1?hit=245&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-f84f060',
#   'https://open.overheid.nl/Details/oep-84b741ec-047f-4100-acf9-56fc9f84f060/1?hit=246&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-9f43b43',
#   'https://open.overheid.nl/Details/oep-2370cb3bdaf27a3ec88fc162baf5f36e19f43b43/1?hit=248&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-f7eee19',
#   'https://open.overheid.nl/Details/oep-7a901d48643a2a23cdfe9091c8a6f9ee4f7eee19/2?hit=249&text=klimaatadaptatie&count=50&page=5'),
#  ('tweede_kamer-76a738e',
#   'https://open.overheid.nl/Details/oep-2096006d-c361-485c-94bf-9edd576a738e/1?hit=260&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-99c241f',
#   'https://open.overheid.nl/Details/oep-b1a2f762022049cea364eb9ddd5cfded799c241f/2?hit=262&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-2a38fbf',
#   'https://open.overheid.nl/Details/oep-5198ecda-31f2-4096-bce3-8fe8c2a38fbf/1?hit=264&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-ad90d75',
#   'https://open.overheid.nl/Details/oep-24fdbf4bf4e1085b7599c2b7caa070865ad90d75/2?hit=265&text=klimaatadaptatie&count=50&page=6'),
#  ('buitenlandse_zaken-6d9ab13',
#   'https://open.overheid.nl/Details/ronl-b7f9ace9c705169fe7c926345c01ae8236d9ab13/1?hit=266&text=klimaatadaptatie&count=50&page=6'),
#  ('infrastructuur_en_waterstaat-7b7abd2',
#   'https://open.overheid.nl/Details/ronl-b39baabd-3b10-420d-81ff-c4f047b7abd2/1?hit=268&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-ced518a',
#   'https://open.overheid.nl/Details/oep-54194eb2-6ace-4a81-978a-5e8eeced518a/1?hit=270&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-d02d15b',
#   'https://open.overheid.nl/Details/oep-2ff8bbb03ed332b645d56ee7915548e24d02d15b/1?hit=272&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-e365a5b',
#   'https://open.overheid.nl/Details/oep-5920775b0ae86d43b69f166f9168748e3e365a5b/2?hit=273&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-6de7ca5',
#   'https://open.overheid.nl/Details/oep-c8c2d5e8821b227910135c860ec128a3f6de7ca5/2?hit=274&text=klimaatadaptatie&count=50&page=6'),
#  ('infrastructuur_en_waterstaat-6285d1a',
#   'https://open.overheid.nl/Details/ronl-0c5086b3029ab6a4ab28d52838ce44d5e6285d1a/1?hit=276&text=klimaatadaptatie&count=50&page=6'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-af664cd',
#   'https://open.overheid.nl/Details/ronl-1b48e421-9fb6-49cf-a47a-0a049af664cd/1?hit=277&text=klimaatadaptatie&count=50&page=6'),
#  ('financiën-936316d',
#   'https://open.overheid.nl/Details/ronl-1a0e63f7-7dbc-4c8c-a59e-c4d56936316d/1?hit=278&text=klimaatadaptatie&count=50&page=6'),
#  ('infrastructuur_en_waterstaat-8aee7e7',
#   'https://open.overheid.nl/Details/ronl-0a711d174fa96f8558d724e38c38503ec8aee7e7/6?hit=282&text=klimaatadaptatie&count=50&page=6'),
#  ('eerste_kamer-4f6671e',
#   'https://open.overheid.nl/Details/oep-205db7a9-6df7-47d5-9a33-04a524f6671e/1?hit=289&text=klimaatadaptatie&count=50&page=6'),
#  ('eerste_kamer-3653f70',
#   'https://open.overheid.nl/Details/oep-29cb1625b7a04aaa9ac44e74f873349823653f70/1?hit=296&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-775dd99',
#   'https://open.overheid.nl/Details/oep-4ab4d1c3b38152d7c18422c2933e57db6775dd99/1?hit=297&text=klimaatadaptatie&count=50&page=6'),
#  ('tweede_kamer-e1783e4',
#   'https://open.overheid.nl/Details/oep-43490c05b4a67ca05aef4226f2f54142be1783e4/1?hit=301&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-3257e8c',
#   'https://open.overheid.nl/Details/oep-c46771932c3171a6050af3efd6ccadf483257e8c/2?hit=303&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-60a054d',
#   'https://open.overheid.nl/Details/oep-e3c3d4c888093b76b782521e48b39510a60a054d/1?hit=305&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-25c0a8b',
#   'https://open.overheid.nl/Details/oep-d50b1fa4bc08058bfeff1e40f9ebc2dca25c0a8b/2?hit=306&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-dac05e5',
#   'https://open.overheid.nl/Details/oep-e3f91e28c15e288082a758ac7b777444edac05e5/1?hit=307&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-b2d79a9',
#   'https://open.overheid.nl/Details/oep-2a2caf5314aea18bf03ccda134ada43f8b2d79a9/1?hit=308&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-497bb8d',
#   'https://open.overheid.nl/Details/oep-39fce0097962b2e06da94dd64333e4aa8497bb8d/1?hit=309&text=klimaatadaptatie&count=50&page=7'),
#  ('infrastructuur_en_waterstaat-294ac74',
#   'https://open.overheid.nl/Details/ronl-archief-71556419-c851-4c5a-a5d9-fa2d2294ac74/1?hit=310&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-7065561',
#   'https://open.overheid.nl/Details/oep-52231d442cee8b52a81ec34e772f756cf7065561/1?hit=314&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-9f66650',
#   'https://open.overheid.nl/Details/oep-dd4a8d12a016acbbb6300258b6473dac59f66650/1?hit=320&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-b4d7eb8',
#   'https://open.overheid.nl/Details/oep-4f826e10b9575ed5904fed21ec52696f3b4d7eb8/1?hit=322&text=klimaatadaptatie&count=50&page=7'),
#  ('buitenlandse_zaken-a98dd71',
#   'https://open.overheid.nl/Details/ronl-8d2e12567cf34251f9252815676721f10a98dd71/2?hit=323&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-9c2a187',
#   'https://open.overheid.nl/Details/oep-41a8ca7e4d7cd55ab057caaeea8b31b159c2a187/1?hit=324&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-ef09252',
#   'https://open.overheid.nl/Details/oep-450ef57b-f8a2-49f4-a250-0ef8aef09252/1?hit=325&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-d7a3f88',
#   'https://open.overheid.nl/Details/oep-6e58d115ec9de267f0ef44b46392be864d7a3f88/1?hit=327&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-769d1d0',
#   'https://open.overheid.nl/Details/oep-52cf2a103e1daf5bc2f1b41245818471c769d1d0/1?hit=330&text=klimaatadaptatie&count=50&page=7'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-ab6a79f',
#   'https://open.overheid.nl/Details/ronl-008a3cc2-6ea4-477d-ad9f-691e8ab6a79f/1?hit=332&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-9142198',
#   'https://open.overheid.nl/Details/oep-39fc9763b615e073fa9c55e762f07f2079142198/1?hit=337&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-9e3894f',
#   'https://open.overheid.nl/Details/oep-5fdf343e-040f-4aee-a858-7f6919e3894f/1?hit=339&text=klimaatadaptatie&count=50&page=7'),
#  ('infrastructuur_en_waterstaat-4281bce',
#   'https://open.overheid.nl/Details/24bba0d2-c298-4ce0-bf1f-da0614281bce/2?hit=343&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-1e8df6e',
#   'https://open.overheid.nl/Details/oep-4d1d6d14a41c664d2cb403d65a3d8b6eb1e8df6e/2?hit=344&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-68fb4c7',
#   'https://open.overheid.nl/Details/oep-15b920fe476e4d768dcdc6ccbe1ae542e68fb4c7/2?hit=347&text=klimaatadaptatie&count=50&page=7'),
#  ('tweede_kamer-f22e599',
#   'https://open.overheid.nl/Details/oep-2d65e8a077b8f5f3dea43a9e1cb162d15f22e599/1?hit=351&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-8e9d78f',
#   'https://open.overheid.nl/Details/oep-423de8dd-10d6-4463-8f6b-4f0168e9d78f/1?hit=355&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-6ec660f',
#   'https://open.overheid.nl/Details/oep-00f7e6a99d261f8cea5d478fadfd628106ec660f/1?hit=357&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-35fe7c8',
#   'https://open.overheid.nl/Details/oep-9fd4dc39a8d8c15748d98b257370a349835fe7c8/2?hit=359&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-85774e4',
#   'https://open.overheid.nl/Details/oep-7cdbc1005476a0f4715734a155b2295e685774e4/1?hit=363&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-d0bc94f',
#   'https://open.overheid.nl/Details/oep-00095edd-6ed6-4bb0-8e66-20197d0bc94f/1?hit=364&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-9c8fbb9',
#   'https://open.overheid.nl/Details/oep-df06cc76-c9f5-4a35-8a17-a08a59c8fbb9/1?hit=369&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-bb8ded2',
#   'https://open.overheid.nl/Details/oep-505436dd-728d-4ba6-88c3-b4f8cbb8ded2/1?hit=371&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-ba7f280',
#   'https://open.overheid.nl/Details/oep-75e59b3c-023b-4f91-a309-44912ba7f280/1?hit=374&text=klimaatadaptatie&count=50&page=8'),
#  ('eerste_kamer-ff6c87c',
#   'https://open.overheid.nl/Details/oep-21d592ee0961f91d9f1799a4ba1b9f8aeff6c87c/1?hit=376&text=klimaatadaptatie&count=50&page=8'),
#  ('eerste_kamer-f586936',
#   'https://open.overheid.nl/Details/oep-7cfb1738860ed2853bacc6eef0b7f7366f586936/1?hit=377&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-bd8c5f7',
#   'https://open.overheid.nl/Details/oep-c552a71f8c6df6e96e74db346b682de8dbd8c5f7/1?hit=379&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-e20f29e',
#   'https://open.overheid.nl/Details/oep-c8783baccb547acb6689f76219d4fbe16e20f29e/2?hit=384&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-ce79253',
#   'https://open.overheid.nl/Details/oep-fa94c1674b29c9f47bc1dd70a278622edce79253/1?hit=385&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-a74c062',
#   'https://open.overheid.nl/Details/oep-40df2187-a134-453f-9b29-d2404a74c062/1?hit=386&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-88aa453',
#   'https://open.overheid.nl/Details/oep-d1f676e16eb819b00a17c033c1bc8813c88aa453/1?hit=387&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-1b67351',
#   'https://open.overheid.nl/Details/oep-f49abaea2ed9d3c778fcad68ed325909c1b67351/1?hit=391&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-d66d236',
#   'https://open.overheid.nl/Details/oep-76c4a333c70d0182b8f17c52022841221d66d236/2?hit=392&text=klimaatadaptatie&count=50&page=8'),
#  ('eerste_kamer-2bd8b04',
#   'https://open.overheid.nl/Details/oep-1ada1a829ef3a0354255a89768306932d2bd8b04/2?hit=393&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-22b4646',
#   'https://open.overheid.nl/Details/oep-2ea397e8d6af08ce8b855908cc73d5f8122b4646/1?hit=394&text=klimaatadaptatie&count=50&page=8'),
#  ('tweede_kamer-fb56ce7',
#   'https://open.overheid.nl/Details/oep-13716c9dc9a92e43b914cb46bab600860fb56ce7/1?hit=396&text=klimaatadaptatie&count=50&page=8'),
#  ('eerste_kamer-8c9571a',
#   'https://open.overheid.nl/Details/oep-b3ab5efa-ac9f-4e8e-a117-1ab418c9571a/1?hit=401&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-d03296f',
#   'https://open.overheid.nl/Details/oep-b0ac961b-e20e-4b6f-9846-1b8b8d03296f/1?hit=402&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-a8e58c6',
#   'https://open.overheid.nl/Details/oep-a6a792a49e6341d52fa6a3200fb138d0ea8e58c6/1?hit=403&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-31712c2',
#   'https://open.overheid.nl/Details/oep-0c9001da323a1306f604d1b476b422ead31712c2/2?hit=405&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-15c644a',
#   'https://open.overheid.nl/Details/oep-97d814318de0b6aefdbbd91d87632172715c644a/2?hit=407&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-a149e55',
#   'https://open.overheid.nl/Details/oep-5855f3c8174a99480851940f0c7581feaa149e55/1?hit=411&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-99dedfc',
#   'https://open.overheid.nl/Details/oep-a4d57d8d3032e92c01d00b90068db3f1d99dedfc/2?hit=412&text=klimaatadaptatie&count=50&page=9'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-99f202c',
#   'https://open.overheid.nl/Details/ronl-d55bcb30-8eab-4375-a7b9-bc81699f202c/1?hit=416&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-8982ae7',
#   'https://open.overheid.nl/Details/oep-f6595dc374c3d1d338c1996e4e3cd83538982ae7/1?hit=417&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-aff8b99',
#   'https://open.overheid.nl/Details/oep-0ec2141e-a9eb-422e-9e5f-45748aff8b99/1?hit=419&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-f7658c6',
#   'https://open.overheid.nl/Details/oep-1655a444d8b79d9112e04ea0796765679f7658c6/1?hit=426&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-ac5696f',
#   'https://open.overheid.nl/Details/oep-27bb681d25f4baec19283a3fdb626f54aac5696f/1?hit=432&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-dc5595c',
#   'https://open.overheid.nl/Details/oep-368e7545dcd0323718a4119de7cb5bfd7dc5595c/2?hit=433&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-e3ee351',
#   'https://open.overheid.nl/Details/oep-66f84fc95a5c31c47d8070b9d214db581e3ee351/2?hit=435&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-c5e22b0',
#   'https://open.overheid.nl/Details/oep-9be76d9892f2c63179ea3be3d2f8f8d4ac5e22b0/1?hit=437&text=klimaatadaptatie&count=50&page=9'),
#  ('rijkswaterstaat-79a6454',
#   'https://open.overheid.nl/Details/woo-idx-718330c55b826b24e4cd86fbe0e09c86979a6454/1?hit=438&text=klimaatadaptatie&count=50&page=9'),
#  ('sociale_zaken_en_werkgelegenheid-a87015d',
#   'https://open.overheid.nl/Details/ronl-409e513d-6cfe-43eb-8937-05c16a87015d/1?hit=445&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-5b09c6c',
#   'https://open.overheid.nl/Details/oep-d8a8e5a706ab2ce6a52fff19e9ec595645b09c6c/1?hit=446&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-0eb94c3',
#   'https://open.overheid.nl/Details/oep-a71c50df5e6d521530655377930986df90eb94c3/2?hit=447&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-6f66077',
#   'https://open.overheid.nl/Details/oep-0643ab80-b57b-4ff2-ac59-dca256f66077/1?hit=450&text=klimaatadaptatie&count=50&page=9'),
#  ('tweede_kamer-d8cd378',
#   'https://open.overheid.nl/Details/oep-9ee148351c4ffb1edca27ba146f6f5716d8cd378/1?hit=452&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-2b71839',
#   'https://open.overheid.nl/Details/oep-8fe83aa7282c8362bc45a771abe3964d92b71839/1?hit=458&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-d994282',
#   'https://open.overheid.nl/Details/oep-17b307e88178710f0aebddb84ec4aec64d994282/1?hit=463&text=klimaatadaptatie&count=50&page=10'),
#  ('eerste_kamer-f645188',
#   'https://open.overheid.nl/Details/oep-7f8bd5e57af72674fe5e044838bb7df06f645188/2?hit=469&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-2b94691',
#   'https://open.overheid.nl/Details/oep-81cba977-a744-4e28-a2a2-540e52b94691/1?hit=470&text=klimaatadaptatie&count=50&page=10'),
#  ('eerste_kamer-9d96abe',
#   'https://open.overheid.nl/Details/oep-0a010038-821f-4770-afae-a4c709d96abe/1?hit=476&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-05ad027',
#   'https://open.overheid.nl/Details/oep-655a51de7855f6ef74c39833ad123f30d05ad027/1?hit=477&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-c8916c0',
#   'https://open.overheid.nl/Details/oep-39dd2ac94f27197df00a9dc078a0c0310c8916c0/1?hit=478&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-14d0aa7',
#   'https://open.overheid.nl/Details/oep-b1984a6962b138e29f5229b61fc256d3314d0aa7/1?hit=480&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-2546477',
#   'https://open.overheid.nl/Details/oep-37f29a2f3d7766d29b43c2d501e30cde22546477/1?hit=482&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-dc35801',
#   'https://open.overheid.nl/Details/oep-a4625340bcb20ec6ea8ebe154aee7b765dc35801/1?hit=483&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-cce91f7',
#   'https://open.overheid.nl/Details/oep-31d733e1e8f6a55ec2a708ac00317bc28cce91f7/2?hit=484&text=klimaatadaptatie&count=50&page=10'),
#  ('onderwijs_cultuur_en_wetenschap-6db941f',
#   'https://open.overheid.nl/Details/ronl-c7665525-2fb0-4e24-b94d-f60ba6db941f/1?hit=489&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-38904e0',
#   'https://open.overheid.nl/Details/oep-4a5d2c8492fb4e103ea0d1d06df3457c438904e0/1?hit=492&text=klimaatadaptatie&count=50&page=10'),
#  ('infrastructuur_en_waterstaat-1450bb4',
#   'https://open.overheid.nl/Details/ronl-e560b0db66ca7e6a46403752a3cbabb831450bb4/1?hit=495&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-356d30d',
#   'https://open.overheid.nl/Details/oep-413cf0317b9d579bf225f398c41f8ad73356d30d/1?hit=498&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-1f89c35',
#   'https://open.overheid.nl/Details/oep-37da921fd35634fca1b824bc83a2785081f89c35/2?hit=499&text=klimaatadaptatie&count=50&page=10'),
#  ('tweede_kamer-158e61b',
#   'https://open.overheid.nl/Details/oep-15bcadf3-9e0e-4c2b-820a-dc6a7158e61b/1?hit=501&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-3f89450',
#   'https://open.overheid.nl/Details/oep-4fb39d49e76a7b032760de7000e7d89db3f89450/2?hit=503&text=klimaatadaptatie&count=50&page=11'),
#  ('eerste_kamer-fa35f92',
#   'https://open.overheid.nl/Details/oep-d978af57c8721dfea4c64518cc7354ed8fa35f92/1?hit=504&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-4d9476c',
#   'https://open.overheid.nl/Details/oep-023f47f4-c6fd-4fd8-a057-de7924d9476c/1?hit=509&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-c393466',
#   'https://open.overheid.nl/Details/oep-f4750e9e585d77917c3a6c7f2e090427dc393466/1?hit=510&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-ffbc3a8',
#   'https://open.overheid.nl/Details/oep-61c8c7beff82f31d5576938678f70070dffbc3a8/2?hit=513&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-24ff75e',
#   'https://open.overheid.nl/Details/oep-9dddd393-7f1d-4c84-a077-d6dfe24ff75e/1?hit=516&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-b7617be',
#   'https://open.overheid.nl/Details/oep-8a1e28d3706a9e991ad34288063ddc647b7617be/1?hit=518&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-2b5b336',
#   'https://open.overheid.nl/Details/oep-6ef2285adee112056b34d664f7b9b780e2b5b336/2?hit=519&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-d4bab25',
#   'https://open.overheid.nl/Details/oep-42698bb0fc3dce5e2086fc915bfd4522cd4bab25/1?hit=520&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-9f4ab27',
#   'https://open.overheid.nl/Details/oep-528b8149e53c637bb97c7b4bc39f54bb69f4ab27/2?hit=522&text=klimaatadaptatie&count=50&page=11'),
#  ('eerste_kamer-bd359a4',
#   'https://open.overheid.nl/Details/oep-75359755e59ab2569f89ee2a7b8c8e526bd359a4/1?hit=528&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-9e7bea1',
#   'https://open.overheid.nl/Details/oep-9c3e551fcf5ceaa03ca1873b26de1f9b49e7bea1/2?hit=530&text=klimaatadaptatie&count=50&page=11'),
#  ('eerste_kamer-ac3dc41',
#   'https://open.overheid.nl/Details/oep-062e4eeb064220187e1a7354f2ef1d9bbac3dc41/1?hit=533&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-f69318f',
#   'https://open.overheid.nl/Details/oep-a2033ce7e2b4448dae38f7e5d33c626a1f69318f/2?hit=535&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-0d7463e',
#   'https://open.overheid.nl/Details/oep-5719a36d-221c-42cb-8388-bb66e0d7463e/1?hit=537&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-77bb5ec',
#   'https://open.overheid.nl/Details/oep-bbd75f3b77e135de2652e2b01b5da4e4677bb5ec/1?hit=539&text=klimaatadaptatie&count=50&page=11'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-10b6d7a',
#   'https://open.overheid.nl/Details/ronl-59b3033c-0826-4624-ba7f-41aec10b6d7a/1?hit=540&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-3544d4d',
#   'https://open.overheid.nl/Details/oep-2eeaccf24715b0e4f9466a194f94ab3973544d4d/1?hit=541&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-c29b3f4',
#   'https://open.overheid.nl/Details/oep-33857bdced48f527ab7817d7d5817da99c29b3f4/2?hit=542&text=klimaatadaptatie&count=50&page=11'),
#  ('eerste_kamer-6c1aa90',
#   'https://open.overheid.nl/Details/oep-0bbdda9be83da1cb1aca4d7f80881adf96c1aa90/2?hit=543&text=klimaatadaptatie&count=50&page=11'),
#  ('infrastructuur_en_waterstaat-0f05f0d',
#   'https://open.overheid.nl/Details/ronl-e792001a-8696-4c52-beb4-c1b800f05f0d/1?hit=545&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-5f64b3a',
#   'https://open.overheid.nl/Details/oep-33ed3419d03f9e313e213f986869c624b5f64b3a/2?hit=546&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-e92efbc',
#   'https://open.overheid.nl/Details/oep-bb6abd5fc3e02aeb5a9f8acbfaea70e51e92efbc/2?hit=547&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-81e302f',
#   'https://open.overheid.nl/Details/oep-4b1e7b6dd51ef1d9047204f3430e4238e81e302f/1?hit=549&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-cf7d2e0',
#   'https://open.overheid.nl/Details/oep-061c8dc3-2298-422d-a094-12c56cf7d2e0/1?hit=550&text=klimaatadaptatie&count=50&page=11'),
#  ('tweede_kamer-c64aae5',
#   'https://open.overheid.nl/Details/oep-dee49185-2b4f-43ad-ba8b-bdd63c64aae5/1?hit=551&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-fd24303',
#   'https://open.overheid.nl/Details/oep-e065e788e7022f391a22e3b937bd26a37fd24303/2?hit=552&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-cf7b6be',
#   'https://open.overheid.nl/Details/oep-91fa57b169bd12611de941dc4ffbacc4fcf7b6be/2?hit=555&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-425209f',
#   'https://open.overheid.nl/Details/oep-f0e3d1220368f40918ff166e9c8a4e9e4425209f/1?hit=557&text=klimaatadaptatie&count=50&page=12'),
#  ('buitenlandse_zaken-5c626d4',
#   'https://open.overheid.nl/Details/ronl-83565b2e-11cb-45da-afb4-49e505c626d4/1?hit=558&text=klimaatadaptatie&count=50&page=12'),
#  ('landbouw_natuur_en_voedselkwaliteit-0edb66a',
#   'https://open.overheid.nl/Details/ronl-09959135-db9d-4a9d-8b4b-aa58e0edb66a/1?hit=559&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-4c4f29c',
#   'https://open.overheid.nl/Details/oep-abbe59b631cc11a28018b373a21eef8624c4f29c/1?hit=562&text=klimaatadaptatie&count=50&page=12'),
#  ('eerste_kamer-58437fa',
#   'https://open.overheid.nl/Details/oep-d12485c43a4be31f4b9b8f2cc733a93ef58437fa/1?hit=563&text=klimaatadaptatie&count=50&page=12'),
#  ('landbouw_natuur_en_voedselkwaliteit-e75911f',
#   'https://open.overheid.nl/Details/ronl-0fc2084ae254222a45676ac50b712a576e75911f/1?hit=565&text=klimaatadaptatie&count=50&page=12'),
#  ('ronl-archief-6677b67',
#   'https://open.overheid.nl/Details/ronl-archief-3fc7da4b-54dc-4526-a05e-6d0936677b67/1?hit=566&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-e3bfbb7',
#   'https://open.overheid.nl/Details/oep-65ac025be08f5d2cb8328f9332f09611ae3bfbb7/2?hit=567&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-c272e3d',
#   'https://open.overheid.nl/Details/oep-b9315fe5745dadb7974ef7b4efb4cb451c272e3d/2?hit=569&text=klimaatadaptatie&count=50&page=12'),
#  ('rijkswaterstaat-41dfa50',
#   'https://open.overheid.nl/Details/woo-idx-e2c88cd03f3b96566e39108512ead390241dfa50/1?hit=571&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-e42be7b',
#   'https://open.overheid.nl/Details/oep-0c966a1cfa7af3677bee3b795aecdca95e42be7b/1?hit=572&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-badf169',
#   'https://open.overheid.nl/Details/oep-a1d98dd1b72d4a6c0fa1a1c944285e839badf169/1?hit=573&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-cb65172',
#   'https://open.overheid.nl/Details/oep-16df59aaf01d3c92de2cad9bdbe99a357cb65172/2?hit=575&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-b3bfc4d',
#   'https://open.overheid.nl/Details/oep-f4ed35c0cdc9db146e4e84d60939d4b46b3bfc4d/1?hit=576&text=klimaatadaptatie&count=50&page=12'),
#  ('eerste_kamer-08af32d',
#   'https://open.overheid.nl/Details/oep-fc4bd4b144028131cf372727a168f6eef08af32d/2?hit=577&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-0e3f700',
#   'https://open.overheid.nl/Details/oep-82faeb157f4d25c0c2adc6e492b911ae50e3f700/1?hit=580&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-6ebb37d',
#   'https://open.overheid.nl/Details/oep-357c7d81bbb32d2d312d80f0c720f1a476ebb37d/1?hit=582&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-d151075',
#   'https://open.overheid.nl/Details/oep-180dab13e63e12b71485f4a1e467b3090d151075/1?hit=583&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-e92f4af',
#   'https://open.overheid.nl/Details/oep-aee30f9d4406ae26488a17e10cc0ef77ce92f4af/1?hit=584&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-4ce9767',
#   'https://open.overheid.nl/Details/oep-c0177c502cc4dc0bec2b3a7033121158f4ce9767/1?hit=585&text=klimaatadaptatie&count=50&page=12'),
#  ('eerste_kamer-86cf090',
#   'https://open.overheid.nl/Details/oep-742fe073fc4a52c68b41c8904a0da75f886cf090/1?hit=586&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-139f003',
#   'https://open.overheid.nl/Details/oep-2813ef52-f8c4-47a4-aa08-00791139f003/1?hit=591&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-f7041cc',
#   'https://open.overheid.nl/Details/oep-fa6b58bdda420b7a08acf5b8b446da689f7041cc/1?hit=592&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-65963a7',
#   'https://open.overheid.nl/Details/oep-a2eae3614f2ff403f25f4adbf4102553b65963a7/1?hit=593&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-10a96e6',
#   'https://open.overheid.nl/Details/oep-19dcc582109b3b3ad9b8cc9240f4be6e110a96e6/2?hit=594&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-33fc0ef',
#   'https://open.overheid.nl/Details/oep-11ee546c-7988-44ef-8988-a907a33fc0ef/1?hit=595&text=klimaatadaptatie&count=50&page=12'),
#  ('eerste_kamer-66045d2',
#   'https://open.overheid.nl/Details/oep-bc1456e9d70e1e7a2c864526fdee3b46666045d2/1?hit=597&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-3499699',
#   'https://open.overheid.nl/Details/oep-677e82a9049906e5a3f2ca1434c0f0fa53499699/2?hit=598&text=klimaatadaptatie&count=50&page=12'),
#  ('tweede_kamer-ec5360b',
#   'https://open.overheid.nl/Details/oep-ca157ae6a161f127d9a7a982999aaec47ec5360b/2?hit=601&text=klimaatadaptatie&count=50&page=13'),
#  ('eerste_kamer-2e54bfb',
#   'https://open.overheid.nl/Details/oep-68779e27f6a4bed6cdc6456fdb5693a3a2e54bfb/1?hit=604&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-ab9309c',
#   'https://open.overheid.nl/Details/oep-5a1e53c3fccaca20704e156f202b7ce29ab9309c/1?hit=605&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-a9aab17',
#   'https://open.overheid.nl/Details/oep-1bdf131e-216b-4a4b-aa49-ef82ca9aab17/1?hit=608&text=klimaatadaptatie&count=50&page=13'),
#  ('landbouw_natuur_en_voedselkwaliteit-22a6031',
#   'https://open.overheid.nl/Details/ed0b6e82-d9d6-4cef-bcb5-9ff0a22a6031/4?hit=611&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-bc58c42',
#   'https://open.overheid.nl/Details/oep-2ada26f08d64bd89034dcd33e8dad5acfbc58c42/1?hit=613&text=klimaatadaptatie&count=50&page=13'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-e3e0b0e',
#   'https://open.overheid.nl/Details/ronl-7441025595f1322b53eeb0ba16edd6261e3e0b0e/1?hit=615&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-36b90fa',
#   'https://open.overheid.nl/Details/oep-00c3a3ca173cc8df329b937da091da9a036b90fa/1?hit=621&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-4f78800',
#   'https://open.overheid.nl/Details/oep-33c1e5fa6bcffd8b2635eace79577a9d34f78800/1?hit=623&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-978663d',
#   'https://open.overheid.nl/Details/oep-6c188511-375c-43ed-b9fc-caece978663d/1?hit=625&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-ebfba8b',
#   'https://open.overheid.nl/Details/oep-59c50682139342e4f2e8ff58bd3bf096aebfba8b/1?hit=627&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-60a3062',
#   'https://open.overheid.nl/Details/oep-582013a694578b4a8d66d0fed4d0bf68460a3062/2?hit=628&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-4349569',
#   'https://open.overheid.nl/Details/oep-bf615670a9fdb3fe258750e33cc22687f4349569/2?hit=629&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-a69d3a6',
#   'https://open.overheid.nl/Details/oep-5eca1905dc53f81c788ec973f4bc190d0a69d3a6/1?hit=631&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-5787f01',
#   'https://open.overheid.nl/Details/oep-658bf096ad7295f77c38e2b935067e9bb5787f01/2?hit=634&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-e68cd10',
#   'https://open.overheid.nl/Details/oep-248df3e3c26cff618c7ced3f58215afaee68cd10/1?hit=635&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-355c2ab',
#   'https://open.overheid.nl/Details/oep-5ad6ba5f9c330087cd58da7d7b1ea8a36355c2ab/1?hit=636&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-970638a',
#   'https://open.overheid.nl/Details/oep-53a533d5c2460d4d06124d7b71b79d995970638a/1?hit=638&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-d3e13e7',
#   'https://open.overheid.nl/Details/oep-eba06e7bfab3a78dc57dea67ef60356cbd3e13e7/2?hit=641&text=klimaatadaptatie&count=50&page=13'),
#  ('infrastructuur_en_waterstaat-65428ab',
#   'https://open.overheid.nl/Details/ronl-efe79ae5ca9cf00396c735bdc9dd5d52365428ab/1?hit=642&text=klimaatadaptatie&count=50&page=13'),
#  ('infrastructuur_en_waterstaat-4dcdc37',
#   'https://open.overheid.nl/Details/ronl-d539832e340c27f78f415fee02a265ab64dcdc37/2?hit=643&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-c621877',
#   'https://open.overheid.nl/Details/oep-b956c771d150363d177e8cfb0ab75e7a0c621877/1?hit=644&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-08a6bab',
#   'https://open.overheid.nl/Details/oep-099c6323-04a8-45db-8dad-a3ff908a6bab/1?hit=646&text=klimaatadaptatie&count=50&page=13'),
#  ('tweede_kamer-36660f8',
#   'https://open.overheid.nl/Details/oep-9b114cf5ee8ea64c2e10e1a7b606a4e5136660f8/2?hit=651&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-80a0027',
#   'https://open.overheid.nl/Details/oep-c10ed4f46122fe1e956fdeed4e23a151280a0027/1?hit=652&text=klimaatadaptatie&count=50&page=14'),
#  ('landbouw_natuur_en_voedselkwaliteit-c9d9291',
#   'https://open.overheid.nl/Details/ronl-d2e6a04b-2533-429d-9659-51a8cc9d9291/1?hit=655&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-f2e1ec0',
#   'https://open.overheid.nl/Details/oep-a61a492e-a734-4474-a40b-163a1f2e1ec0/1?hit=659&text=klimaatadaptatie&count=50&page=14'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-e27c9e8',
#   'https://open.overheid.nl/Details/ronl-f20ad877-d582-4643-b463-004ade27c9e8/1?hit=662&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-f1f7ba6',
#   'https://open.overheid.nl/Details/oep-c810aeeeff4081e2321ac506029be8cedf1f7ba6/1?hit=665&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-2812dfc',
#   'https://open.overheid.nl/Details/oep-f560b9d53a2b671f94f0e0f1295d1cb592812dfc/2?hit=671&text=klimaatadaptatie&count=50&page=14'),
#  ('eerste_kamer-da02345',
#   'https://open.overheid.nl/Details/oep-b1d317f56ef7b80803003bfe8daaddfebda02345/1?hit=672&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-8a6c6d4',
#   'https://open.overheid.nl/Details/oep-51c722ab1b0a8881f511048919f584ab58a6c6d4/2?hit=674&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-2a91304',
#   'https://open.overheid.nl/Details/oep-c1a02bb2de2ec957817444035b6d9d0752a91304/1?hit=681&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-85b151c',
#   'https://open.overheid.nl/Details/oep-07e2ce9f-597e-4d69-ac20-4d10785b151c/1?hit=682&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-8703b37',
#   'https://open.overheid.nl/Details/oep-f2f86b274f58d70cc97668d85deeb33378703b37/1?hit=685&text=klimaatadaptatie&count=50&page=14'),
#  ('infrastructuur_en_waterstaat-a0475dc',
#   'https://open.overheid.nl/Details/ronl-d6ef278c-4462-46ca-8426-139f9a0475dc/1?hit=686&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-66d535d',
#   'https://open.overheid.nl/Details/oep-edf1c6d82770cba0550be7a1345fc45a266d535d/1?hit=693&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-94af3f5',
#   'https://open.overheid.nl/Details/oep-986fd3d5290792b60d9e44f26502ca13f94af3f5/1?hit=695&text=klimaatadaptatie&count=50&page=14'),
#  ('tweede_kamer-8351848',
#   'https://open.overheid.nl/Details/oep-9e58a47d298e1bc79dd8223f31de134f18351848/1?hit=705&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-7882b02',
#   'https://open.overheid.nl/Details/oep-9d1bdd44-4e64-43a8-853b-c67b47882b02/1?hit=709&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-929e63d',
#   'https://open.overheid.nl/Details/oep-1a53d8930b494f17f2b64afff08a9212e929e63d/1?hit=710&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-970f417',
#   'https://open.overheid.nl/Details/oep-8797f7c9-db70-4914-aa7e-415b7970f417/1?hit=713&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-4605786',
#   'https://open.overheid.nl/Details/oep-f965ddb5fb264b0d6dbf314f49d93a7444605786/1?hit=715&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-3d4e85e',
#   'https://open.overheid.nl/Details/oep-5144c339ab7f730f7b6ae6db713ebdd103d4e85e/1?hit=716&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-a281456',
#   'https://open.overheid.nl/Details/oep-fe82b8744957423af9600a2a24a61de90a281456/1?hit=719&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-5e3bc6a',
#   'https://open.overheid.nl/Details/oep-54d6361b8ba1619da0a09cb7e9a4735505e3bc6a/1?hit=720&text=klimaatadaptatie&count=50&page=15'),
#  ('infrastructuur_en_waterstaat-ce1109a',
#   'https://open.overheid.nl/Details/ronl-daed6746-875a-4d9e-b98d-edc79ce1109a/1?hit=722&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-dd7b451',
#   'https://open.overheid.nl/Details/oep-e743654f512b0caeb7bcc45fae4bfbfa8dd7b451/2?hit=728&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-8cbdf71',
#   'https://open.overheid.nl/Details/oep-9e3660ca-2ce2-4159-b3e9-c689c8cbdf71/1?hit=729&text=klimaatadaptatie&count=50&page=15'),
#  ('landbouw_natuur_en_voedselkwaliteit-ec0e88a',
#   'https://open.overheid.nl/Details/ronl-0051cfcbac76727498c21047f03954596ec0e88a/1?hit=732&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-2ac98c3',
#   'https://open.overheid.nl/Details/oep-ffe66946c0e9e764a84d28779edbd72842ac98c3/1?hit=734&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-e300ffd',
#   'https://open.overheid.nl/Details/oep-1a6eceec4c7cb5ba32b43817d64f264fbe300ffd/1?hit=736&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-806b451',
#   'https://open.overheid.nl/Details/oep-a495c5b2dd446aead99fe8482982058c9806b451/2?hit=738&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-03fe689',
#   'https://open.overheid.nl/Details/oep-338eead2-0e57-4f61-8138-05d6203fe689/1?hit=740&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-5b3b937',
#   'https://open.overheid.nl/Details/oep-a041611bf8686042b41323935b7091dba5b3b937/1?hit=744&text=klimaatadaptatie&count=50&page=15'),
#  ('eerste_kamer-78874a8',
#   'https://open.overheid.nl/Details/oep-c862acb091bc19a23a3c64328a377c58678874a8/1?hit=745&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-51056a8',
#   'https://open.overheid.nl/Details/oep-4201d2a0e2da333db5a67c78eb06b7ad251056a8/2?hit=747&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-ef40f79',
#   'https://open.overheid.nl/Details/oep-3a8365f06a4d84bf1177be79405b564f4ef40f79/1?hit=748&text=klimaatadaptatie&count=50&page=15'),
#  ('tweede_kamer-d1992a3',
#   'https://open.overheid.nl/Details/oep-86262bd6-4857-41d7-8dea-a0fa0d1992a3/1?hit=750&text=klimaatadaptatie&count=50&page=15'),
#  ('eerste_kamer-305ea82',
# ...
#   'https://open.overheid.nl/Details/oep-469ad184-08f2-4ac2-85d9-40334fd85b0c/1?hit=2200&text=klimaatadaptatie&count=50&page=44'),
#  ('tweede_kamer-5a6dfb0',
#   'https://open.overheid.nl/Details/oep-5b35f4cc43d9e781ecbe5629c6ca7052b5a6dfb0/2?hit=2207&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-4544293',
#   'https://open.overheid.nl/Details/oep-72b60f8c2701cf84db8233cdbf1a1457c4544293/1?hit=2208&text=klimaatadaptatie&count=50&page=45'),
#  ('ronl-archief-9f4944a',
#   'https://open.overheid.nl/Details/ronl-archief-f86a2f05-dacd-4829-bd8e-3784d9f4944a/1?hit=2209&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-c2db424',
#   'https://open.overheid.nl/Details/oep-22daf2d9e3f8f00cb640b87fc0c6855c1c2db424/1?hit=2215&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-cd7cb5c',
#   'https://open.overheid.nl/Details/oep-5cf62621f5d53a5a5bb11e6850da84c75cd7cb5c/2?hit=2216&text=klimaatadaptatie&count=50&page=45'),
#  ('eerste_kamer-6cf7154',
#   'https://open.overheid.nl/Details/oep-a646dac1dfe568fcb04add34b0f2cd47c6cf7154/1?hit=2217&text=klimaatadaptatie&count=50&page=45'),
#  ('eerste_kamer-47e3bf9',
#   'https://open.overheid.nl/Details/oep-6b45f608f4313ae1b0240e3ea170df66147e3bf9/1?hit=2220&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-790efb9',
#   'https://open.overheid.nl/Details/oep-e663bcd8-387a-4e50-b0d4-28aa3790efb9/1?hit=2224&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-d5f5018',
#   'https://open.overheid.nl/Details/oep-ab1af43e-ee0f-40e8-bd31-a1743d5f5018/1?hit=2225&text=klimaatadaptatie&count=50&page=45'),
#  ('eerste_kamer-51c0451',
#   'https://open.overheid.nl/Details/oep-053ab11d-546e-421f-8c01-34c5951c0451/1?hit=2227&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-b714319',
#   'https://open.overheid.nl/Details/oep-59435c56c6ac5f0814997b02813fe360fb714319/1?hit=2228&text=klimaatadaptatie&count=50&page=45'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-2c5c789',
#   'https://open.overheid.nl/Details/ronl-cbf714e4-fdd7-47c9-b827-c447b2c5c789/1?hit=2229&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-e20166b',
#   'https://open.overheid.nl/Details/oep-0cd79979e8ebeb4fe7ac63862096c9a43e20166b/2?hit=2230&text=klimaatadaptatie&count=50&page=45'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-940173d',
#   'https://open.overheid.nl/Details/ronl-febeddf723d244314f1dbfecf8aedd3f7940173d/2?hit=2235&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-14b60d9',
#   'https://open.overheid.nl/Details/oep-e9fbf3034e5c3a80bccc89188505ad78814b60d9/1?hit=2236&text=klimaatadaptatie&count=50&page=45'),
#  ('infrastructuur_en_waterstaat-a7876a6',
#   'https://open.overheid.nl/Details/ronl-83deb29c-cf1b-4abc-b421-40870a7876a6/1?hit=2242&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-a4ec800',
#   'https://open.overheid.nl/Details/oep-108168895b089d380019dca7897a2c6cca4ec800/1?hit=2246&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-2265bd1',
#   'https://open.overheid.nl/Details/oep-54cd67904572f0701ceba37d60a2efd042265bd1/2?hit=2247&text=klimaatadaptatie&count=50&page=45'),
#  ('eerste_kamer-d761878',
#   'https://open.overheid.nl/Details/oep-73e0e9fa52bb39d1dc909b4ebc224a4bbd761878/2?hit=2248&text=klimaatadaptatie&count=50&page=45'),
#  ('rijkswaterstaat-61e5fcd',
#   'https://open.overheid.nl/Details/woo-idx-b6378fea83f10de7f479a8b1788deccb761e5fcd/1?hit=2249&text=klimaatadaptatie&count=50&page=45'),
#  ('tweede_kamer-955ba07',
#   'https://open.overheid.nl/Details/oep-c26fc264b1d897938627a96cff1cffb0c955ba07/1?hit=2254&text=klimaatadaptatie&count=50&page=46'),
#  ('landbouw_natuur_en_voedselkwaliteit-e5d0621',
#   'https://open.overheid.nl/Details/be15439a-7a93-4b40-8e26-26a9ae5d0621/1?hit=2256&text=klimaatadaptatie&count=50&page=46'),
#  ('economische_zaken_en_klimaat-6decd7d',
#   'https://open.overheid.nl/Details/ronl-archief-cfc02def-be68-40ac-84ff-b1ec76decd7d/1?hit=2259&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-c222d3a',
#   'https://open.overheid.nl/Details/oep-a30f74423713712d95e19089411663900c222d3a/1?hit=2262&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-15c87ab',
#   'https://open.overheid.nl/Details/oep-4a5d43eab22f089a80bf66a76aba2713015c87ab/2?hit=2264&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-219268b',
#   'https://open.overheid.nl/Details/oep-dac8ce5662be6e4d6cae94a2e08dac816219268b/2?hit=2265&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-1542dd8',
#   'https://open.overheid.nl/Details/oep-31082139-9704-4e9a-8d4f-bf5211542dd8/1?hit=2268&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-7c43bb4',
#   'https://open.overheid.nl/Details/oep-8b1396a7759a57a0df8b0f9293c4948ed7c43bb4/2?hit=2269&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-549f56e',
#   'https://open.overheid.nl/Details/oep-8fe8d31e-0557-4011-a31d-d5f11549f56e/1?hit=2270&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-3800c46',
#   'https://open.overheid.nl/Details/oep-9fccc64f-e220-41d0-ad02-3559e3800c46/1?hit=2271&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-2f392a0',
#   'https://open.overheid.nl/Details/oep-c9b6b96d-6a8f-490c-bec4-529b92f392a0/1?hit=2272&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-157a5f0',
#   'https://open.overheid.nl/Details/oep-5cfeb7f9-cb32-402d-b095-066fe157a5f0/1?hit=2273&text=klimaatadaptatie&count=50&page=46'),
#  ('eerste_kamer-39af664',
#   'https://open.overheid.nl/Details/oep-a0ce17ee-17c7-42be-aa50-18f3539af664/1?hit=2274&text=klimaatadaptatie&count=50&page=46'),
#  ('eerste_kamer-2e35cf3',
#   'https://open.overheid.nl/Details/oep-bcf2dc6706b301cda6379beb8b1782a3e2e35cf3/1?hit=2276&text=klimaatadaptatie&count=50&page=46'),
#  ('volksgezondheid_welzijn_en_sport-15c1c6c',
#   'https://open.overheid.nl/Details/ee6dc972-3d78-471c-9275-3a84d15c1c6c/2?hit=2279&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-7fd5fb8',
#   'https://open.overheid.nl/Details/oep-2b398c31e5a55e617ae7f3c3410c792917fd5fb8/1?hit=2284&text=klimaatadaptatie&count=50&page=46'),
#  ('eerste_kamer-e2818da',
#   'https://open.overheid.nl/Details/oep-4e00f6f3-f49c-4156-8f46-1228ae2818da/1?hit=2285&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-67147de',
#   'https://open.overheid.nl/Details/oep-c90fe2e94d661e8bd3904a28aab459f7e67147de/1?hit=2286&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-3b48bcd',
#   'https://open.overheid.nl/Details/oep-ef5069cb-f185-4bd1-9075-2be113b48bcd/1?hit=2289&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-50c216d',
#   'https://open.overheid.nl/Details/oep-a3e1614f15aa94df8c9787031fae9a16150c216d/1?hit=2293&text=klimaatadaptatie&count=50&page=46'),
#  ('tweede_kamer-6465b25',
#   'https://open.overheid.nl/Details/oep-ef1171d69e409eea3600f84ddad43dbb26465b25/1?hit=2303&text=klimaatadaptatie&count=50&page=47'),
#  ('eerste_kamer-b1401b8',
#   'https://open.overheid.nl/Details/oep-edb7109d1cc8f5204561ab7df23faf9c9b1401b8/1?hit=2304&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-316b749',
#   'https://open.overheid.nl/Details/oep-49ec416908bd51642c8566992def1bdeb316b749/1?hit=2308&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-defecb1',
#   'https://open.overheid.nl/Details/oep-a5cdeee97da25e4925c90652db5e22c6edefecb1/1?hit=2309&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-a621fdc',
#   'https://open.overheid.nl/Details/oep-98b02f052547442946e5822d30a44ceb5a621fdc/2?hit=2311&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-2661dbd',
#   'https://open.overheid.nl/Details/oep-eb2dc09f3676f7ef620726d1965e7888e2661dbd/1?hit=2312&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-e25f4db',
#   'https://open.overheid.nl/Details/oep-215af1c463ab31cfb3c10b048afa50977e25f4db/1?hit=2313&text=klimaatadaptatie&count=50&page=47'),
#  ('eerste_kamer-764d751',
#   'https://open.overheid.nl/Details/oep-d9d70812-bbb8-4011-b121-4d4a3764d751/1?hit=2314&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-7885678',
#   'https://open.overheid.nl/Details/oep-f897fa61308e5e01a02007a3ed683dc757885678/2?hit=2319&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-f8099a0',
#   'https://open.overheid.nl/Details/oep-6b2c54118141659be58fa799f1fffac45f8099a0/1?hit=2320&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-1a432fc',
#   'https://open.overheid.nl/Details/oep-92eefff8d574c2b020b9ff3f8b76cb9c11a432fc/2?hit=2329&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-ea8bbe4',
#   'https://open.overheid.nl/Details/oep-cb4e61f92931712ac0e9be025ce8618a9ea8bbe4/1?hit=2332&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-661260c',
#   'https://open.overheid.nl/Details/oep-53ad3ca9bb8ee6541c12dc454403b77fd661260c/1?hit=2341&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-41ce05b',
#   'https://open.overheid.nl/Details/oep-47931a5aa813773b216ca744326fd0a1541ce05b/1?hit=2343&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-2c6d508',
#   'https://open.overheid.nl/Details/oep-9ac220685b622aa0668cfe3738165c24e2c6d508/2?hit=2344&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-418f57c',
#   'https://open.overheid.nl/Details/oep-e02367ebe30142edc9bea75cb27e19630418f57c/2?hit=2345&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-2db06b4',
#   'https://open.overheid.nl/Details/oep-5227595fd566f0409d0d044577fe445ce2db06b4/3?hit=2346&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-632c9d0',
#   'https://open.overheid.nl/Details/oep-aa29eacb4cf36e7567463149e92ad60c4632c9d0/1?hit=2347&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-cb402ad',
#   'https://open.overheid.nl/Details/oep-d0689fb115c9709684c1c4047167de0cccb402ad/2?hit=2348&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-b9f26c1',
#   'https://open.overheid.nl/Details/oep-8ba58fc2-7b49-4919-9d2e-57fc3b9f26c1/1?hit=2349&text=klimaatadaptatie&count=50&page=47'),
#  ('tweede_kamer-be38108',
#   'https://open.overheid.nl/Details/oep-4d55c3d1cc9498adfcf8d4ffaccdd1371be38108/1?hit=2351&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-aef4d64',
#   'https://open.overheid.nl/Details/oep-d2841709-df98-4173-a1a9-17980aef4d64/1?hit=2352&text=klimaatadaptatie&count=50&page=48'),
#  ('onderwijs_cultuur_en_wetenschap-b315188',
#   'https://open.overheid.nl/Details/ronl-2c93e997915ec14456e766ab0833bb1a6b315188/2?hit=2353&text=klimaatadaptatie&count=50&page=48'),
#  ('binnenlandse_zaken_en_koninkrijksrelaties-626f491',
#   'https://open.overheid.nl/Details/oep-bdd63b3a367d942c68f31299d7d9263b8626f491/1?hit=2354&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-405b254',
#   'https://open.overheid.nl/Details/oep-0cc5a357-8a98-41fe-b46a-9b79d405b254/1?hit=2357&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-929faae',
#   'https://open.overheid.nl/Details/oep-3d856c25b6ed53cae95878a61a566cb2d929faae/1?hit=2360&text=klimaatadaptatie&count=50&page=48'),
#  ('economische_zaken_en_klimaat-f8220ef',
#   'https://open.overheid.nl/Details/ronl-d5992178-0e2c-4409-9649-445d0f8220ef/1?hit=2363&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-e8a31c2',
#   'https://open.overheid.nl/Details/oep-10fa4f1781e6719b6726efd36794baa1be8a31c2/2?hit=2366&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-96ee6bb',
#   'https://open.overheid.nl/Details/oep-1c3ba74d-8d16-46c7-bbd9-fd82f96ee6bb/1?hit=2369&text=klimaatadaptatie&count=50&page=48'),
#  ('algemene_zaken-18cc0fc',
#   'https://open.overheid.nl/Details/ronl-154e68ceef7e1d022d4d8cf3ef41ec80118cc0fc/1?hit=2372&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-c6a9d28',
#   'https://open.overheid.nl/Details/oep-30c1132d7d677c853206806b6f25a6e23c6a9d28/1?hit=2376&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-0c563f4',
#   'https://open.overheid.nl/Details/oep-a97c81662ec62a59ef415ec2ed323dfb50c563f4/1?hit=2378&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-5081f07',
#   'https://open.overheid.nl/Details/oep-b10a4d16f9287ef0032e93dfd2ae7c7155081f07/1?hit=2381&text=klimaatadaptatie&count=50&page=48'),
#  ('ronl-archief-229c8cd',
#   'https://open.overheid.nl/Details/ronl-archief-6ba1926d-be28-401d-90b7-45429229c8cd/1?hit=2383&text=klimaatadaptatie&count=50&page=48'),
#  ('ronl-archief-7ee6d34',
#   'https://open.overheid.nl/Details/ronl-archief-dabfa31d-2f6b-4f69-be16-971897ee6d34/1?hit=2384&text=klimaatadaptatie&count=50&page=48'),
#  ('infrastructuur_en_waterstaat-5b9ba39',
#   'https://open.overheid.nl/Details/ronl-1a6f2f58-65a6-4bcb-8d69-9e8755b9ba39/1?hit=2386&text=klimaatadaptatie&count=50&page=48'),
#  ('infrastructuur_en_waterstaat-9cd4f7b',
#   'https://open.overheid.nl/Details/ronl-ec214e62c9883e70518bdb19cda556ec39cd4f7b/2?hit=2387&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-ae3b7cc',
#   'https://open.overheid.nl/Details/oep-d1194590-d0e5-4416-836f-12752ae3b7cc/1?hit=2388&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-c76f321',
#   'https://open.overheid.nl/Details/oep-9048b39a73f09024511fc5c69ceaf0f01c76f321/2?hit=2391&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-167b2fb',
#   'https://open.overheid.nl/Details/oep-e8c9db0d57d20241d8df086b2fa3418c4167b2fb/2?hit=2392&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-17da88e',
#   'https://open.overheid.nl/Details/oep-fe7e86abd32ad7e3fba84ed9090f74f2217da88e/1?hit=2393&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-e2729ca',
#   'https://open.overheid.nl/Details/oep-cf3e4b52fddc394ba9df14a26d4cde0b2e2729ca/1?hit=2394&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-d2d48a5',
#   'https://open.overheid.nl/Details/oep-00936cd48a03b8cf0dc0e9ed0beda2474d2d48a5/1?hit=2396&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-ce69585',
#   'https://open.overheid.nl/Details/oep-a378cd2f-f18e-42be-a1a7-222ecce69585/1?hit=2398&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-8ae8eee',
#   'https://open.overheid.nl/Details/oep-149b5b534dc94eac47ef524c0e78e7a908ae8eee/1?hit=2400&text=klimaatadaptatie&count=50&page=48'),
#  ('tweede_kamer-399c49a',
#   'https://open.overheid.nl/Details/oep-d46c6d044449885d06582e4fd048b6c1f399c49a/1?hit=2401&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-dc8da98',
#   'https://open.overheid.nl/Details/oep-bd058549-dd79-4c90-8ab8-099c1dc8da98/1?hit=2405&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-ab5b5b6',
#   'https://open.overheid.nl/Details/oep-10a649e9eb55e882871b124e2b2502bf4ab5b5b6/1?hit=2406&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-9ebb43c',
#   'https://open.overheid.nl/Details/oep-b35cdbf1526a8243d4dad127c320458779ebb43c/1?hit=2407&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-2fc3243',
#   'https://open.overheid.nl/Details/oep-5de471b0c862f039f3e9a00c91cfab90e2fc3243/1?hit=2408&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-c3d1aa1',
#   'https://open.overheid.nl/Details/oep-d2c55b53f1ec6d27f2e8abcfad909073bc3d1aa1/1?hit=2409&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-77c0c87',
#   'https://open.overheid.nl/Details/oep-2c485a2a5e79914e7a0651546c4e926a377c0c87/1?hit=2412&text=klimaatadaptatie&count=50&page=49'),
#  ('eerste_kamer-e8db9eb',
#   'https://open.overheid.nl/Details/oep-adf7008c8e6de7722bc2a0114a21a82a3e8db9eb/1?hit=2413&text=klimaatadaptatie&count=50&page=49'),
#  ('eerste_kamer-f029b94',
#   'https://open.overheid.nl/Details/oep-e4427e40416d2d11a37d73798eb2edceaf029b94/1?hit=2414&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-25c411d',
#   'https://open.overheid.nl/Details/oep-6b9d45f9a42aabf1bd91e681598f57f8625c411d/1?hit=2418&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-ac75f9a',
#   'https://open.overheid.nl/Details/oep-4c38b074-5b05-4e80-b364-912ebac75f9a/1?hit=2422&text=klimaatadaptatie&count=50&page=49'),
#  ('tweede_kamer-e58282c',
#   'https://open.overheid.nl/Details/oep-bf66091233265a59c087d854b4657058fe58282c/1?hit=2423&text=klimaatadaptatie&count=50&page=49'),
#  ('infrastructuur_en_waterstaat-201f6eb',
#   'https://open.overheid.nl/Details/ronl-c7b86756-3542-4562-8af3-22694201f6eb/1?hit=2427&text=klimaatadaptatie&count=50&page=49'),
#  ...]

# %%
def get_files_notubiz(tuples):
    id, url = tuples[0], tuples[1]
    try:
        url_ = url.replace(".html", ".pdf")
        response = requests.get(url_)
    except requests.exceptions.TooManyRedirects:
        return

    with open(f"./pdf/{id}.pdf", 'wb') as f:
        f.write(response.content)
    time.sleep(5)
    return

# %%
for t in tqdm.tqdm(still_to_check["overheid"]):
    if t[0] not in already_existing:
        
        get_files_notubiz(t)

# %%
response = requests.get("https://open.overheid.nl/Details/ronl-02a120f0-60c4-42a4-99bf-dd682a0f21b2/1?hit=9&text=klimaatadaptatie&page=1&count=50")
