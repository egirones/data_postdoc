# %%
import pandas as pd
import os

# %%
df = pd.read_csv("/Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/metadata/all.tsv",  sep="\t", index_col=0)

# %%
df.head()
# Out:
#                                                 name  \
# 0              Subsidieregeling groene schoolpleinen
# 1  Bestemmingsplan ‘Kom Etten, locatie Palmlaan e...
# 2  Rectificatie van de Omgevingsverordening Frysl...
# 3  Ondermandaatbesluit directeur DCMR Milieudiens...
# 4  Algemene Verordening Ondergrondse Infrastructu...
#
#                                                  url           old_id  \
# 0  https://zoek.officielebekendmakingen.nl/gmb-20...  gmb-2024-425476
# 1  https://zoek.officielebekendmakingen.nl/gmb-20...  gmb-2024-423342
# 2  https://zoek.officielebekendmakingen.nl/prb-20...   prb-2024-15413
# 3  https://zoek.officielebekendmakingen.nl/bgr-20...    bgr-2024-1873
# 4  https://zoek.officielebekendmakingen.nl/gmb-20...  gmb-2024-424073
#
#                                    id        date                organization  \
# 0                 neder-betuwe-425476  2024-10-09                neder-betuwe
# ...

# %%
files = [i.split(".")[0] for i in os.listdir("./klimaatadaptatie/pdf")]

# %%
names = {}
for f in files:
    new_name = df[df.name == f].head(1)["id"]
    if new_name.shape[0] == 1:
        names[f.strip()] = new_name.item()

# %%
len(names.keys())
# Out:
# 126

# %%
! ls /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf
# Out:
# (collectie)-10.pdf
# (collectie)-13.pdf
# (collectie)-4.pdf
# (collectie)-6.pdf
# (collectie)-9.pdf
# 03 06 2020 Bijlage II Eindrapportage 2019 OD NZKG Eindverslag en -rekening-1.pdf
# 05a MRAWerkplan Begroting 2020 20190705-1.pdf
# 05a MRAWerkplan Begroting 2020 20190705-2.pdf
# 1. Jaarrekening 2022 DEF.pdf
# 1.Voorlopige Jaarstukken 2022 Vervoerregio Amsterdam .pdf
# 2. bijlage RIB 2020-68 factsheet klimaatadaptatie Landsmeer.pdf
# 2. dUitvoeringsagenda Nationale Omgevingsvisie (NOVI).pdf
# 20.30 uur presentatie Zaans Klimaatakkoord in de raad.pdf
# 20210211 - BOT sessie gemeenteraad Uitvoeringsplan Klimaatadaptatie Landsmeer.2.pdf
# 20210215 Agenda en actieplan klimaatadaptatie Aalsmeer.pdf
# 20231102 Overzicht debatpunten MenA Begroting ZB 1 en 2 november 2023-1.pdf
# 21bb14968 Bijlage behorende bij 21bb14967 over Concept-Ruimtelijke onderbouwing aanvraag omgevingsvergunning t.b.v. ontwikkeling Pop-Up theater '40-45' aan de Keileweg.pdf
# 220518 Jaarstukken 2021-006b DEF.pdf
# ...

# %%
n
# Out:
# 'Bijlage 6 Bestemmingsplan Lint Krommenie Bijlagen bij toelichting 7909632'

# %%
os.path.exists("/Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/Antwoordbrief Beantwoording artikel 51 vragen PvdD Busbrug De Binding en de natuur in Polder Westzaan.pdf")
# Out:
# False

# %%
os.path.exists(f"/Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/{n}.pdf".replace(" ", "^ "))
# Out:
# False

# %%
for n in names:
    try:
        os.rename(f"./klimaatadaptatie/pdf/{n.strip()}.pdf", f"./klimaatadaptatie/pdf/{names[n]}.pdf")
    except FileNotFoundError:
       print(os.path.exists(f"/Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/{n}.pdf".replace(" ", "\^ ")))
       print(f"/Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/{n}.pdf")
# Out:
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/Beeldkwaliteitsplan Zaankwartier (Meneba) bijlage.pdf
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/20190411 MRA Agenda Discussienotitie.pdf
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/Verslag Raad 15 februari 2018.pdf
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/Raadsvoorstel gebiedsoverstijgende kosten.pdf
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/Raadsbesluit Vaststellen bestemmingsplan Jaspersstraat.pdf
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/Raadsbesluit Begroting 2021-2024.pdf
# False
# /Users/esalasgirones/Documents/work/repos/crawlers/data/klimaatadaptatie/pdf/B2 Uitvoeringsplan Klimaatadaptatie Zaanstreek-Waterland 2021-2024.pdf
# False
# ...

# %%
# !ls
# Out:
# convert_text.py            make_metadata_pickle.ipynb
# get_missing_overheid.ipynb rename.ipynb
# klimaatadaptatie
